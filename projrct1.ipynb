# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel(r"D:\data science 2025\git_repository\data-science-project-\data_total.xlsx",sheet_name="Sheet1")
df
# Out:
#         country  search index        keyword
# 0         China           100  deep learning
# 1   South Korea            33  deep learning
# 2      Ethiopia            15  deep learning
# 3     Hong Kong            12  deep learning
# 4       Tunisia            10  deep learning
# ..          ...           ...            ...
# 57       Russia             1  deep learning
# 58      Czechia             1  deep learning
# 59       Poland             1  deep learning
# 60       Mexico             1  deep learning
# 61       Brazil             1  deep learning
#
# [62 rows x 3 columns]

# %%
df1=pd.read_excel(r"D:\data science 2025\git_repository\data-science-project-\data_total.xlsx",sheet_name="Sheet2")
df1.head()
# Out:
#        country  search index  keyword
# 0        China           100  chatgpt
# 1    Sri Lanka            94  chatgpt
# 2  Philippines            80  chatgpt
# 3        Nepal            79  chatgpt
# 4     Pakistan            77  chatgpt

# %%
df2=pd.read_excel(r"D:\data science 2025\git_repository\data-science-project-\data_total.xlsx",sheet_name='Sheet3')
df2.head()
# Out:
#        country  search index keyword
# 0        China           100      ML
# 1    St Helena            39      ML
# 2  South Korea            36      ML
# 3    Singapore            35      ML
# 4     Ethiopia            34      ML

# %%
df3=pd.read_excel(r"D:\data science 2025\git_repository\data-science-project-\data_total.xlsx",sheet_name='Sheet4')
df3.head()
# Out:
#        country  search index        keyword
# 0    Singapore           100  generative ai
# 1    St Helena            77  generative ai
# 2        China            63  generative ai
# 3  South Korea            48  generative ai
# 4    Hong Kong            48  generative ai

# %%
df4=pd.read_excel(r"D:\data science 2025\git_repository\data-science-project-\data_total.xlsx",sheet_name="Sheet5")
df4.head()
# Out:
#      country  search index      keyword
# 0   Zimbabwe           100  datascience
# 1      India            87  datascience
# 2      Kenya            75  datascience
# 3   Ethiopia            68  datascience
# 4  Singapore            67  datascience

# %%
df_final=pd.concat([df,df4,df2,df3,df1],ignore_index=True)
df_final
# Out:
#          country  search index        keyword
# 0          China           100  deep learning
# 1    South Korea            33  deep learning
# 2       Ethiopia            15  deep learning
# 3      Hong Kong            12  deep learning
# 4        Tunisia            10  deep learning
# ..           ...           ...            ...
# 336       Poland            10        chatgpt
# 337         Iran             8        chatgpt
# 338        Japan             7        chatgpt
# 339      Ukraine             7        chatgpt
# 340       Russia             3        chatgpt
#
# [341 rows x 3 columns]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 341 entries, 0 to 340
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       341 non-null    object
#  1   search index  341 non-null    int64
#  2   keyword       341 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 8.1+ KB

# %%
df_final.notnull()
# Out:
#      country  search index  keyword
# 0       True          True     True
# 1       True          True     True
# 2       True          True     True
# 3       True          True     True
# 4       True          True     True
# ..       ...           ...      ...
# 336     True          True     True
# 337     True          True     True
# 338     True          True     True
# 339     True          True     True
# 340     True          True     True
#
# [341 rows x 3 columns]

# %%
df_final.to_csv("data.csv", index=False)

# %%
import matplotlib.pyplot as plt

# %%
plt.title('top country vs search index(deep learning)')
plt.xlabel('country')
plt.ylabel('search index')
plt.bar(df['country'].head(),df['search index'].head())
# Out:
# <BarContainer object of 5 artists>

# %%
plt.title('top country vs search index(chatgpt)')
plt.xlabel('country')
plt.ylabel('search index')
plt.bar(df1['country'].head(),df1['search index'].head())
# Out:
# <BarContainer object of 5 artists>

# %%
plt.title('top country vs search index(ML)')
plt.xlabel('country')
plt.ylabel('search index')
plt.bar(df2['country'].head(),df2['search index'].head())
# Out:
# <BarContainer object of 5 artists>

# %%
plt.title('top country vs search index(generative ai)')
plt.xlabel('country')
plt.ylabel('search index')
plt.bar(df3['country'].head(),df3['search index'].head())
# Out:
# <BarContainer object of 5 artists>

# %%
plt.title('top country vs search index(data science)')
plt.xlabel('country')
plt.ylabel('search index')
plt.bar(df4['country'].head(),df4['search index'].head())
# Out:
# <BarContainer object of 5 artists>
